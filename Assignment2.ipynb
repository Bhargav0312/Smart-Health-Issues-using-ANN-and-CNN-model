# %%
from glob import glob
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

stock_files=sorted(glob('DS\\data*.csv'))
stock_files
for i in stock_files:
    df=pd.read_csv(i)
    print(df)
#     pd.concat((pd.read_csv(file).assign(filename=file)
#          for file in stock_files),ignore_index=True,sort=False)
#     data = df
#     scaler = MinMaxScaler()
#     print(scaler.fit(data))
array=df.values
array
X=array[:,0:1]
y=array[:,0]
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.3, random_state=42)
scaler = MinMaxScaler(feature_range=(0, 1)) 
print(scaler.fit(array))
# Out:
#                                  OptimizedValue:1606.0
# 0    [[156 499 284  25 300  40 346 108 190 458 358 ...
# 1      449 225 487  54 497 420 207 204 175 423 301 ...
# 2      345 435 295 443 397  63  35 491 264 113 179 ...
# 3     [219 400  62  99  34 432 259 315 319  88 378 ...
# 4      320 418 230 294 334 312 313 121 146 330 131 ...
# ..                                                 ...
# 145    495 251 464 290 279 330 251 327 319  24 466 ...
# 146    243  72  68 334  33  79  96 443 387 101 387 ...
# 147   [ 72 354 129 489 136 101 375 244 282  34 355 ...
# 148     77  89 366 240 419 225 325 136 214  24  85 ...
# 149     94 395 468  25 315 348 312 420 295 327  68 ...
#
# [150 rows x 1 columns]
#                                  OptimizedValue:1714.0
# 0    [[ 84  46 272  52 329 217 387 107 337  69 199 ...
# 1      119 100  75 175 202 402 401 426  68 289 338 ...
# 2       89  26 451 444  43 215  91 105 275 277 344 ...
# 3     [249 280 180 270 158 229 196 358 253 309 248 ...
# ...

# %%
import pandas as pd
pd.concat((pd.read_csv(file).assign(filename=file)
         for file in stock_files),ignore_index=True,sort=False)

# %%
import csv
for i in stock_files:
    f=open(glob('DS\\data*.csv'))
    csv_f=csv.reader(f)
    df=[]
    for row in csv_f:
        print (row[0])
    f.close()

# %%
df=[]
df=pd.read_csv('DS\\data0.csv')
for i in df:
    print (i)
